# %%
import numpy as np
import pandas as pd

# %%
alltrails = pd.read_csv(r"C:\IT2\chatlyn\chatlyn-app\backend\src\datasets\alltrails_top50.csv")
alltrails.head()
# Out:
#                                      name                      location  \
# 0                    Angels Landing Trail            Zion National Park
# 1     Navajo Loop and Queens Garden Trail    Bryce Canyon National Park
# 2                    Devil's Bridge Trail      Coconino National Forest
# 3                      Emerald Lake Trail  Rocky Mountain National Park
# 4  Vernal and Nevada Falls via Mist Trail        Yosemite National Park
#
#   difficulty  length  elevation  reviews  rating    route_type
# 0       Hard     6.9        557    24041     4.9  Out and Back
# 1   Moderate     5.0        198    15818     4.9          Loop
# 2   Moderate     6.3        159    23938     4.7  Out and Back
# 3   Moderate     5.1        214    14549     4.8  Out and Back
# 4       Hard    10.3        673    12978     4.9          Loop

# %%
alltrails.quantile([0.1, 0.9])
# Out:
#      length  elevation  reviews  rating
# 0.1    3.64      190.0   8227.1     4.7
# 0.5    7.65      446.5  10986.0     4.8
